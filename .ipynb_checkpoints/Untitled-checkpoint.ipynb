# %%
import sim
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
all_results = []

ev_scheme = "priority"
for i in range(1, 26):
    current_sim = sim.ParkingSimulation(
        num_regular_spots=26-i, 
        num_ev_spots=i, 
        ev_scheme=ev_scheme, 
        static_pricing=True, 
        alpha=1.0, 
        base_rate=1.5
    )
    
    current_sim.run(visualize=False)
    
    all_results.append({
        "ev_spots": i,
        "ice_spots": 26-i,
        "ice_revenue": current_sim.revenue_ice,
        "ev_parking_revenue": current_sim.revenue_ev_parking,
        "ev_charging_revenue":  current_sim.revenue_ev_charging,
        "accepted_ice": current_sim.accepted_ice,
        "accepted_ev": current_sim.accepted_ev,
        "rejected_ice_full": current_sim.rejected_ice_full,
        "rejected_ev_full": current_sim.rejected_ev_full,
        "rejected_ice_price": current_sim.rejected_ice_price,
        "rejected_ev_price": current_sim.rejected_ev_price,
        "cost": current_sim.setup_cost
        
    })

# %%
df = pd.DataFrame(all_results)
df['total_revenue'] = df['ice_revenue'] + df['ev_parking_revenue'] + df['ev_charging_revenue']
df['ev_total_revenue'] = df['ev_parking_revenue'] + df['ev_charging_revenue']
df['yearly_rev'] = 52 * df['total_revenue']
df['accepted_ratio_full'] = (df['accepted_ice'] + df['accepted_ev'])/(df['accepted_ice'] + df['accepted_ev'] + df['rejected_ice_full'] + df['rejected_ev_full']) * 100
df['accepted_ice_full'] = (df['accepted_ice'])/(df['accepted_ice'] + df['rejected_ice_full']) * 100
df['accepted_ev_full'] = (df['accepted_ev'])/(df['accepted_ev'] + df['rejected_ev_full']) * 100

# %%
sns.set_theme(style="whitegrid", palette="muted")

plt.figure(figsize=(12, 6))

sns.lineplot(data=df, x='ev_spots', y='total_revenue',  color='blue', linewidth=3, label='Total Revenue')

sns.lineplot(data=df, x='ev_spots', y='ice_revenue', label='ICE Parking Revenue', color='red', linewidth=3, alpha=0.6)
sns.lineplot(data=df, x='ev_spots', y='ev_total_revenue', label='EV Charging Revenue',color='green', linewidth=3, alpha=0.6)

plt.title("Revenue by Number of EV Spots", fontsize=15)
plt.xlabel("Number of EV Spots (Total 26)", fontsize=12)
plt.ylabel("Weekly Revenue ($)", fontsize=12)
plt.legend(frameon=True)

plt.savefig("on_demand_revenue.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Set a modern theme
sns.set_theme(style="whitegrid", palette="muted")

plt.figure(figsize=(12, 6))

# Plot total revenue
sns.lineplot(data=df, x='ev_spots', y='accepted_ratio_full', linewidth=3 ,label='% of accepted vehicles')
sns.lineplot(data=df, x='ev_spots', y='accepted_ice_full',  linewidth=3,label='% of accepted ICE vehicles')
sns.lineplot(data=df, x='ev_spots', y='accepted_ev_full', linewidth=3,label='% of accepted EV vehicles')

plt.title("Spot Allocation", fontsize=15)
plt.xlabel("Number of EV Spots (Total 26)", fontsize=12)
plt.ylabel("%", fontsize=12)
plt.legend(frameon=True)

plt.savefig("on_demand_allocation.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
sns.set_theme(style="whitegrid")
fig, ax1 = plt.subplots(figsize=(12, 6))

sns.lineplot(data=df, x='ev_spots', y='cost', color='red', 
             linewidth=3, label='Initial Investment', ax=ax1)
ax1.set_ylabel('Total Setup Cost ($)', fontsize=12, color='red', fontweight='bold')
ax1.tick_params(axis='y', labelcolor='red')

ax2 = ax1.twinx()
sns.lineplot(data=df, x=df.index, y='yearly_rev', color='blue', 
             linewidth=3, label='Annual Gross Revenue', ax=ax2)
ax2.set_ylabel('Annual Gross Revenue ($)', fontsize=12, color='blue', fontweight='bold')
ax2.tick_params(axis='y', labelcolor='blue')

plt.title("Financial Scaling: Investment vs. Revenue Growth", fontsize=15, pad=20)
ax1.grid(True, alpha=0.3)
ax2.grid(False)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.savefig("on_demand_cost_rev.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
# --- 1. PREPARE NORMALIZED DATA ---
# Define the safe normalization helper to prevent NaN crashes
def safe_normalize(series):
    if series.max() == series.min():
        return 0.0
    return (series - series.min()) / (series.max() - series.min())

# Calculate normalized components
df['norm_rev']  = safe_normalize(df['yearly_rev'])
df['norm_ev_occ']  = safe_normalize(df['accepted_ev_full'])
df['norm_ice_occ']  = safe_normalize(df['accepted_ice_full'])

# Cost logic: 1 is cheap (good), 0 is expensive (bad)
df['norm_cost'] = 1 - safe_normalize(df['cost'])

# --- 2. CALCULATE BALANCE SCORE ---
df['balance_score'] = (df['norm_rev'] * 0.4) + (df['norm_ev_occ'] * 0.2) + (df['norm_ice_occ'] * 0.2) + (df['norm_cost'] * 0.2)

# --- 3. FIND THE BEST INDICES ---8
# Handle the case where On-Demand might produce identical scores
if df['balance_score'].isna().all() or (df['balance_score'].max() == df['balance_score'].min()):
    # If all are equal, default to the configuration with the lowest cost (index 0)
    best_balance_idx = df['cost'].idxmin() 
else:
    best_balance_idx = df['balance_score'].idxmax()

best_profit_idx  = df['yearly_rev'].idxmax()
best_occ_idx     = df['accepted_ratio_full'].idxmax()

# --- 4. EXTRACT VALUES ---
suggested_spots = df.loc[best_balance_idx, 'ev_spots']
max_profit_spots = df.loc[best_profit_idx, 'ev_spots']
max_occ_spots    = df.loc[best_occ_idx, 'ev_spots']

# --- 5. PRINT SUMMARY ---
print(f"=== OPTIMIZATION RESULTS ({ev_scheme.upper()}) ===")
print(f"Max Profit Goal     -> {max_profit_spots} Spots | Rev: ${df.loc[best_profit_idx, 'yearly_rev']:,.0f}")
print(f"Max Occupancy Goal  -> {max_occ_spots} Spots | Occ: {df.loc[best_occ_idx, 'accepted_ratio_full']:.1f}%")
print(f"Minimum Cost Goal   -> {df['ev_spots'].min()} Spots | Cost: ${df['cost'].min():,.0f}")
print("-" * 45)
print(f"SUGGESTED BALANCE   -> {suggested_spots} EV Spots")
print(f"Description: Best trade-off between Rev, Occupancy, and CapEx.")
# Out:
# === OPTIMIZATION RESULTS (PRIORITY) ===
# Max Profit Goal     -> 7 Spots | Rev: $142,769
# Max Occupancy Goal  -> 4 Spots | Occ: 92.2%
# Minimum Cost Goal   -> 1 Spots | Cost: $2,500
# ---------------------------------------------
# SUGGESTED BALANCE   -> 8 EV Spots
# Description: Best trade-off between Rev, Occupancy, and CapEx.

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x='ev_spots', y='balance_score', linewidth=3, color='purple')

plt.axvline(x=suggested_spots, color='red', linestyle='--', label=f'Suggested: {suggested_spots} Spots')

plt.title(f"Optimization Results: Optimal Balance at {suggested_spots} EV Spots", fontsize=14)
plt.xlabel("Number of EV Spots")
plt.ylabel("Balance Score (Normalized)")
plt.legend()

plt.savefig("priority - ideal.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd

ev_scheme = "priority"

OPTIMAL_SPOTS = 8
CAPACITY = 26
# Ensure this matches your simulation duration
SIM_TOTAL_MINUTES = 7 * 24 * 60 
TOTAL_POTENTIAL_MINUTES = CAPACITY * SIM_TOTAL_MINUTES

static_results = []
prices = np.arange(0.5, 5.5, 0.1)

for price in prices:
    current_sim = sim.ParkingSimulation(
        num_regular_spots=CAPACITY - OPTIMAL_SPOTS, 
        num_ev_spots=OPTIMAL_SPOTS, 
        ev_scheme=ev_scheme, 
        static_pricing=True, 
        alpha=1.0, 
        base_rate=price
    )
    
    current_sim.run(visualize=False)
    
    # 1. Calculate Total Yearly Revenue
    total_rev = current_sim.revenue_ice + current_sim.revenue_ev_parking + current_sim.revenue_ev_charging
    
    # --- THE MISSING CALL ---
    # We explicitly call the function you updated in the class
    fullness_ratio = current_sim.get_average_fullness() 

    static_results.append({
        "base_rate": price,
        "total_yearly_rev": total_rev,
        "fullness": fullness_ratio, # Now this will scale correctly!
        "ice_revenue": current_sim.revenue_ice,
        "ev_parking_revenue": current_sim.revenue_ev_parking,
        "ev_charging_revenue": current_sim.revenue_ev_charging,
        "rejected_price_total": current_sim.rejected_ice_price + current_sim.rejected_ev_price
    })

    static_results.append({
        "base_rate": price,
        "total_yearly_rev": total_rev,
        "fullness": fullness_ratio,
        "ice_revenue": current_sim.revenue_ice,
        "ev_parking_revenue": current_sim.revenue_ev_parking,
        "ev_charging_revenue": current_sim.revenue_ev_charging,
        "rejected_price_total": current_sim.rejected_ice_price + current_sim.rejected_ev_price
    })

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ... [Your simulation loop code here] ...

# --- 1. CONVERT TO DATAFRAME ---
df_static = pd.DataFrame(static_results)

# --- 2. CALCULATE STATIC SCORE ---
def norm(series):
    return (series - series.min()) / (series.max() - series.min()) if series.max() != series.min() else 0

df_static['norm_rev'] = norm(df_static['total_yearly_rev'])
df_static['norm_full'] = norm(df_static['fullness'])
df_static['balance_score'] = (df_static['norm_rev'] * 0.5) + (df_static['norm_full'] * 0.5)

# --- 3. EXPORT TO CSV (For your records) ---
df_static.to_csv("static_optimization_results.csv", index=False)

# --- 4. VISUALIZATION ---
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Revenue on the left axis
color_rev = 'tab:blue'
ax1.set_xlabel('Base Rate (€/h)', fontsize=12)
ax1.set_ylabel('Total Yearly Revenue (€)', color=color_rev, fontsize=12)
ax1.plot(df_static['base_rate'], df_static['total_yearly_rev'], color=color_rev, linewidth=3, label='Yearly Revenue')
ax1.tick_params(axis='y', labelcolor=color_rev)
ax1.grid(True, alpha=0.3)

# Plot Fullness on the right axis
ax2 = ax1.twinx() 
color_full = 'tab:red'
ax2.set_ylabel('Average Fullness (%)', color=color_full, fontsize=12)
ax2.plot(df_static['base_rate'], df_static['fullness'] * 100, color=color_full, linewidth=3, label='Fullness (%)')
ax2.tick_params(axis='y', labelcolor=color_full)

# Mark the Optimal Point
best_price = df_static.loc[df_static['balance_score'].idxmax(), 'base_rate']
plt.axvline(x=best_price, color='black', linestyle=':', alpha=0.7, label=f'Optimal Price: €{best_price:.2f}')

plt.title('Static Pricing Optimization: Revenue vs. Fullness', fontsize=14, pad=20)
fig.tight_layout()
plt.savefig("price_optimization_chart.png", dpi=300)
plt.show()

print(f"Optimal Price found at: €{best_price:.2f}/h")
# Out:
# Optimal Static Price: €1.40/h

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
CAPACITY = 26
OPTIMAL_SPOTS = 8
SIM_TOTAL_MINUTES = 7 * 24 * 60 

# Define the Grid
base_rates = np.arange(1.0, 5.0, 0.1)  # 8 price points
alphas = np.arange(0.2, 2.2, 0.2)      # 10 sensitivity levels
dynamic_results = []

print("--- STARTING DYNAMIC GRID SEARCH ---")

for br in base_rates:
    for a in alphas:
        current_sim = sim.ParkingSimulation(
            num_regular_spots=CAPACITY - OPTIMAL_SPOTS, 
            num_ev_spots=OPTIMAL_SPOTS, 
            ev_scheme="priority", 
            static_pricing=False, # DYNAMIC MODE ON
            alpha=a, 
            base_rate=br
        )
        
        current_sim.run(visualize=False)
        
        total_rev = current_sim.revenue_ice + current_sim.revenue_ev_parking + current_sim.revenue_ev_charging
        fullness = current_sim.get_average_fullness()
        
        dynamic_results.append({
            "base_rate": br,
            "alpha": a,
            "total_rev": total_rev,
            "fullness": fullness,
            "score": 0 # We will calculate this after normalization
        })

df_dyn = pd.DataFrame(dynamic_results)

# --- 2. MULTI-VARIABLE NORMALIZATION ---
df_dyn['norm_rev'] = (df_dyn['total_rev'] - df_dyn['total_rev'].min()) / (df_dyn['total_rev'].max() - df_dyn['total_rev'].min())
df_dyn['norm_full'] = (df_dyn['fullness'] - df_dyn['fullness'].min()) / (df_dyn['total_rev'].max() - df_dyn['fullness'].min())

# Balance Score (50/50)
df_dyn['score'] = (df_dyn['norm_rev'] * 0.5) + (df_dyn['norm_full'] * 0.5)

best_idx = df_dyn['score'].idxmax()
best_config = df_dyn.loc[best_idx]

print(f"--- DYNAMIC OPTIMIZATION COMPLETE ---")
print(f"Best Base Rate: €{best_config['base_rate']:.2f}")
print(f"Best Alpha: {best_config['alpha']:.1f}")
print(f"Peak Revenue: €{best_config['total_rev']:,.2f}")
# Out:
# --- STARTING DYNAMIC GRID SEARCH ---
# --- DYNAMIC OPTIMIZATION COMPLETE ---
# Best Base Rate: €2.60
# Best Alpha: 0.6
# Peak Revenue: €2,740.51

# %%
from mpl_toolkits.mplot3d import Axes3D

# 1. Pivot the data so Base Rates are one axis and Alphas are the other
# We use the results from your Dynamic Grid Search
pivot_df = df_dyn.pivot(index='base_rate', columns='alpha', values='total_rev')

# 2. Create the coordinate matrices
X = pivot_df.columns.values  # Alphas
Y = pivot_df.index.values    # Base Rates
X, Y = np.meshgrid(X, Y)
Z = pivot_df.values          # Revenue

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.9)

# Add labels
ax.set_xlabel('Alpha', fontsize=10)
ax.set_ylabel('Base Rate (€/h)', fontsize=10)
ax.set_zlabel('Total Yearly Revenue (€)', fontsize=10)
ax.set_title('Revenue Optimization Surface: Base Rate vs. Alpha', fontsize=14)

# Add a color bar
fig.colorbar(surf, shrink=0.5, aspect=10)

# Adjust the viewing angle to see the peak clearly
ax.view_init(elev=30, azim=135)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 1. Pivot the grid search data for Fullness
pivot_fullness = df_dyn.pivot(index='base_rate', columns='alpha', values='fullness')

# 2. Create Matrices
X_alpha = pivot_fullness.columns.values
Y_price = pivot_fullness.index.values
X_alpha, Y_price = np.meshgrid(X_alpha, Y_price)
Z_fullness = pivot_fullness.values * 100  # Convert to percentage

# 3. Plotting
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot surface (using 'Reds' colormap for occupancy)
surf = ax.plot_surface(X_alpha, Y_price, Z_fullness, cmap='YlOrRd', edgecolor='none', alpha=0.8)

# Labels
ax.set_xlabel('Alpha (Sensitivity)', fontsize=10)
ax.set_ylabel('Base Rate (€/h)', fontsize=10)
ax.set_zlabel('Average Fullness (%)', fontsize=10)
ax.set_title('Fullness Topography: Impact of Price & Sensitivity', fontsize=14)

# Color Bar
fig.colorbar(surf, shrink=0.5, aspect=10, label='Fullness %')

# Set view angle to see the "slope" clearly
ax.view_init(elev=25, azim=45)

plt.show()

# %%
import matplotlib.pyplot as plt

# --- PREPARE DATA ---
# Extract the dynamic results for the specific 'best_alpha' identified in your revenue optimization
df_dynamic_fullness_opt = df_dyn[df_dyn['alpha'] == best_alpha]

plt.figure(figsize=(12, 7))

# Plot Static Fullness (Grey dashed)
plt.plot(df_static['base_rate'], df_static['fullness'] * 100, 
         label='Static Fullness', color='gray', linestyle='--', linewidth=2)

# Plot Dynamic Fullness (Red solid)
plt.plot(df_dynamic_fullness_opt['base_rate'], df_dynamic_fullness_opt['fullness'] * 100, 
         label=f'Dynamic Fullness (Alpha={best_config['alpha']})', color='tab:red', linewidth=3)

# Formatting
plt.axvline(x=best_static_price, color='black', linestyle=':', alpha=0.5, label='Optimal Static Price')
plt.title('Occupancy Comparison: Static vs. Dynamic Pricing', fontsize=14)
plt.xlabel('Base Rate (€/h)', fontsize=12)
plt.ylabel('Average Fullness (%)', fontsize=12)
plt.ylim(0, 105) # Keeps the scale clear
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       1 import matplotlib.pyplot as plt
#       3 # --- PREPARE DATA ---
#       4 # Extract the dynamic results for the specific 'best_alpha' identified in your revenue optimization
# ----> 5 df_dynamic_fullness_opt = df_dyn[df_dyn['alpha'] == best_alpha]
#       7 plt.figure(figsize=(12, 7))
#       9 # Plot Static Fullness (Grey dashed)
#
# NameError: name 'best_alpha' is not defined
